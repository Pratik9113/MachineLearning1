# %%
import pandas as pd
import numpy as np

# %%
data_set = pd.read_csv("/content/Dataset_master.xlsx - Iris Data (1).csv")
data = data_set.copy()
print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.iloc[2:3,2:4] = np.nan
print(data)
data.describe()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.6          3.1           NaN          NaN        NaN
# 3             5.0          3.6           1.4          0.2     setosa
# 4             5.4          3.9           1.7          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 144           6.7          3.0           5.2          2.3  virginica
# 145           6.3          2.5           5.0          1.9  virginica
# 146           6.5          3.0           5.2          2.0  virginica
# 147           6.2          3.4           5.4          2.3  virginica
# 148           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]
#        sepal_length  sepal_width  petal_length  petal_width
# ...

# %%
# want to drop data
data.dropna(inplace = True)
print(data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 3           5.0          3.6           1.4          0.2  setosa
# 4           5.4          3.9           1.7          0.4  setosa
# 5           4.6          3.4           1.4          0.3  setosa

# %%
# reset the indices
data.reset_index(drop = True, inplace = True)
print(data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           5.0          3.6           1.4          0.2  setosa
# 3           5.4          3.9           1.7          0.4  setosa
# 4           4.6          3.4           1.4          0.3  setosa

# %%
data.iloc[2:3,2:4] = np.nan
print(data)
data.describe()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             5.0          3.6           NaN          NaN        NaN
# 3             5.4          3.9           1.7          0.4     setosa
# 4             4.6          3.4           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 143           6.7          3.0           5.2          2.3  virginica
# 144           6.3          2.5           5.0          1.9  virginica
# 145           6.5          3.0           5.2          2.0  virginica
# 146           6.2          3.4           5.4          2.3  virginica
# 147           5.9          3.0           5.1          1.8  virginica
#
# [148 rows x 5 columns]
#        sepal_length  sepal_width  petal_length  petal_width
# ...

# %%
# if your data is nan or you can find mean and median for setosa
data.petal_length.fillna(data.petal_length.mean() , inplace = True)
print(data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5      1.400000          0.2  setosa
# 1           4.9          3.0      1.400000          0.2  setosa
# 2           5.0          3.6      3.806803          NaN     NaN
# 3           5.4          3.9      1.700000          0.4  setosa
# 4           4.6          3.4      1.400000          0.3  setosa

# %%
# filled another nan value only for setosa
temp = data[data.species == 'setosa']
data.petal_width.fillna(temp.petal_width.mean() , inplace = True)
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5      1.400000     0.200000  setosa
# 1           4.9          3.0      1.400000     0.200000  setosa
# 2           5.0          3.6      3.806803     0.246809     NaN
# 3           5.4          3.9      1.700000     0.400000  setosa
# 4           4.6          3.4      1.400000     0.300000  setosa
