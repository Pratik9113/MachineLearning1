# %%
import pandas as pd
iris_df = pd.read_csv('/content/Dataset_master.xlsx - Iris Data (1).csv')
print(iris_df)
print(type(iris_df))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
data_frame = iris_df.copy()

# %%
data_frame.drop(0)
data_frame.head()
#it didnot drop it
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#to avoid this type of problem
new_df = data_frame.drop(0);
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
#index and their access
new_df.index
# Out:
# RangeIndex(start=1, stop=150, step=1)

# %%
new_df.index[0]
# Out:
# 1

# %%
new_df.drop(new_df.index[0], inplace = True )
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
new_df.petal_length > .2
# Out:
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
#        ...
# 145    True
# 146    True
# 147    True
# 148    True
# 149    True
# Name: petal_length, Length: 148, dtype: bool

# %%
new_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    148.000000   148.000000    148.000000   148.000000
# mean       5.854730     3.051351      3.790541     1.212162
# std        0.827695     0.434950      1.754657     0.759332
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
new_df[new_df.petal_width > 0.2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [116 rows x 5 columns]

# %%
new_df[new_df.species == 'virginica']
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
new_df[new_df.species == 'virginica'].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
print(new_df.iloc[0])
# Out:
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object

# %%
print(new_df.loc[2])
# Out:
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object

# %%
print(new_df.loc[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     390                 try:
# --> 391                     return self._range.index(new_key)
#     392                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-5b95bd2d965d> in <cell line: 1>()
# ----> 1 print(new_df.loc[0])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
# ...

# %%
new_df.loc[0] = [2.3, 3.4, 3.2 ,2.3 , 'virginica']
new_df.head()
#nothing will change
#it will goes into the last
new_df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 144           6.3          2.5           5.0          1.9  virginica
# 145           6.5          3.0           5.2          2.0  virginica
# 146           6.2          3.4           5.4          2.3  virginica
# 147           5.9          3.0           5.1          1.8  virginica
# 148           2.3          3.4           3.2          2.3     setosa

# %%
#how to takle it
new_df.reset_index(drop = True , inplace = True)
print(new_df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             2.3          3.4           3.2          2.3  virginica
# 1             4.6          3.1           1.5          0.2     setosa
# 2             5.0          3.6           1.4          0.2     setosa
# 3             5.4          3.9           1.7          0.4     setosa
# 4             4.6          3.4           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 144           6.3          2.5           5.0          1.9  virginica
# 145           6.5          3.0           5.2          2.0  virginica
# 146           6.2          3.4           5.4          2.3  virginica
# 147           5.9          3.0           5.1          1.8  virginica
# 148           2.3          3.4           3.2          2.3     setosa
#
# [149 rows x 5 columns]

# %%
#how to takle it
new_df.reset_index(inplace = True)
print(new_df)
# Out:
#      index  sepal_length  sepal_width  petal_length  petal_width    species
# 0        0           2.3          3.4           3.2          2.3  virginica
# 1        1           4.6          3.1           1.5          0.2     setosa
# 2        2           5.0          3.6           1.4          0.2     setosa
# 3        3           5.4          3.9           1.7          0.4     setosa
# 4        4           4.6          3.4           1.4          0.3     setosa
# ..     ...           ...          ...           ...          ...        ...
# 144    144           6.3          2.5           5.0          1.9  virginica
# 145    145           6.5          3.0           5.2          2.0  virginica
# 146    146           6.2          3.4           5.4          2.3  virginica
# 147    147           5.9          3.0           5.1          1.8  virginica
# 148    148           2.3          3.4           3.2          2.3     setosa
#
# [149 rows x 6 columns]

# %%
new_df.drop(columns = ['index'], inplace = True)
print(new_df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             2.3          3.4           3.2          2.3  virginica
# 1             4.6          3.1           1.5          0.2     setosa
# 2             5.0          3.6           1.4          0.2     setosa
# 3             5.4          3.9           1.7          0.4     setosa
# 4             4.6          3.4           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 144           6.3          2.5           5.0          1.9  virginica
# 145           6.5          3.0           5.2          2.0  virginica
# 146           6.2          3.4           5.4          2.3  virginica
# 147           5.9          3.0           5.1          1.8  virginica
# 148           2.3          3.4           3.2          2.3     setosa
#
# [149 rows x 5 columns]

# %%
new_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.814765     3.055034      3.799329     1.233557
# std        0.916838     0.435182      1.738028     0.762430
# min        2.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
new_df['color']= "white"

# %%
print(new_df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  color
# 0             2.3          3.4           3.2          2.3  virginica  white
# 1             4.6          3.1           1.5          0.2     setosa  white
# 2             5.0          3.6           1.4          0.2     setosa  white
# 3             5.4          3.9           1.7          0.4     setosa  white
# 4             4.6          3.4           1.4          0.3     setosa  white
# ..            ...          ...           ...          ...        ...    ...
# 144           6.3          2.5           5.0          1.9  virginica  white
# 145           6.5          3.0           5.2          2.0  virginica  white
# 146           6.2          3.4           5.4          2.3  virginica  white
# 147           5.9          3.0           5.1          1.8  virginica  white
# 148           2.3          3.4           3.2          2.3     setosa  white
#
# [149 rows x 6 columns]

# %%
del new_df["color"]
new_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.814765     3.055034      3.799329     1.233557
# std        0.916838     0.435182      1.738028     0.762430
# min        2.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(new_df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             2.3          3.4           3.2          2.3  virginica
# 1             4.6          3.1           1.5          0.2     setosa
# 2             5.0          3.6           1.4          0.2     setosa
# 3             5.4          3.9           1.7          0.4     setosa
# 4             4.6          3.4           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 144           6.3          2.5           5.0          1.9  virginica
# 145           6.5          3.0           5.2          2.0  virginica
# 146           6.2          3.4           5.4          2.3  virginica
# 147           5.9          3.0           5.1          1.8  virginica
# 148           2.3          3.4           3.2          2.3     setosa
#
# [149 rows x 5 columns]
