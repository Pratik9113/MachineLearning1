# %%
import pandas as pd

# %%
# importing iris data set
data_set = pd.read_csv("/content/Dataset_master.xlsx - Iris Data (1).csv")
print(data_set)
print(type(data_set))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
data_frame = data_set.copy()
#same data base but two different dataframe

# %%
data_frame.head()
#formated method
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data_frame.head(6)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
data_frame.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
print(data_frame.shape)
# Out:
# (150, 5)

# %%
print(data_frame.reshape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-929debcff373> in <cell line: 1>()
# ----> 1 print(data_frame.reshape)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
print(data_frame.dtypes)
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
print(data_frame.species)
data_frame['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
data_frame.isnull()
# from 5 to 144 we can't see values
data_frame.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data_frame.iloc[0:3,0:4]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
#inplace
data_frame.drop(4,inplace=True)
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
newdf = data_frame
newdf.index
newdf.index[0]
# Out:
# 0

# %%
newdf.petal_length>3.5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 5      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: petal_length, Length: 149, dtype: bool

# %%
newdf.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848993     3.050336      3.774497     1.205369
# std        0.827943     0.432720      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#it gives me all the result
newdf[newdf.petal_length>6.5].describe
#newdf[newdf.petal_length>6.5].describe()
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width    species
# 105           7.6          3.0           6.6          2.1  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica>

# %%
newdf[newdf.species == 'setosa'].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     49.000000    49.000000     49.000000    49.000000
# mean       5.006122     3.414286      1.465306     0.244898
# std        0.356141     0.384057      0.175061     0.108130
# min        4.300000     2.300000      1.000000     0.100000
# 25%        4.800000     3.100000      1.400000     0.200000
# 50%        5.000000     3.400000      1.500000     0.200000
# 75%        5.200000     3.700000      1.600000     0.300000
# max        5.800000     4.400000      1.900000     0.600000

# %%
newdf.head()
newdf.iloc[0] # in terms of position
newdf.loc[9] # label
# Out:
# sepal_length       4.9
# sepal_width        3.1
# petal_length       1.5
# petal_width        0.1
# species         setosa
# Name: 9, dtype: object

# %%
# want to add
newdf.loc[4] = [4.5,3.1,1.5,0.3,'setosa']
print(newdf.head())
#it didn't show
newdf.tail()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           4.5          3.1           1.5          0.3  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           4.5          3.1           1.5          0.3  setosa
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.3          2.5           5.0          1.9  virginica
# 146           6.5          3.0           5.2          2.0  virginica
# 147           6.2          3.4           5.4          2.3  virginica
# 148           5.9          3.0           5.1          1.8  virginica
# 149           4.5          3.1           1.5          0.3     setosa

# %%
newdf.reset_index(drop =True, inplace = True)
print(newdf)
#newdf.drop(columns=["index"])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             4.5          3.1           1.5          0.3     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             4.5          3.1           1.5          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.3          2.5           5.0          1.9  virginica
# 146           6.5          3.0           5.2          2.0  virginica
# 147           6.2          3.4           5.4          2.3  virginica
# 148           5.9          3.0           5.1          1.8  virginica
# 149           4.5          3.1           1.5          0.3     setosa
#
# [150 rows x 5 columns]
# ---------------------------------------------------------------------------
# ...

# %%
#want to delete
del newdf["sepal_width"]
newdf.describe()
# Out:
#        sepal_length  petal_length  petal_width
# count    150.000000    150.000000   150.000000
# mean       5.830000      3.758667     1.199333
# std        0.843829      1.764306     0.762238
# min        4.300000      1.000000     0.100000
# 25%        5.100000      1.525000     0.300000
# 50%        5.800000      4.350000     1.300000
# 75%        6.400000      5.100000     1.800000
# max        7.900000      6.900000     2.500000

# %%
newdf["color"] = 'white'
newdf.describe()
newdf.head(7)
# Out:
#    sepal_length  petal_length  petal_width species  color
# 0           4.5           1.5          0.3  setosa  white
# 1           4.9           1.4          0.2  setosa  white
# 2           4.7           1.3          0.2  setosa  white
# 3           4.6           1.5          0.2  setosa  white
# 4           4.5           1.5          0.3  setosa  white
# 5           4.6           1.4          0.3  setosa  white
# 6           5.0           1.5          0.2  setosa  white

# %%
import numpy as np
newdf.iloc[2:4,2:5] = np.nan
print(newdf.head())
# Out:
#    sepal_length  petal_length  petal_width species  color
# 0           4.5           1.5          0.3  setosa  white
# 1           4.9           1.4          0.2  setosa  white
# 2           4.7           1.3          NaN     NaN    NaN
# 3           4.6           1.5          NaN     NaN    NaN
# 4           4.5           1.5          0.3  setosa  white

# %%
newdf.describe()
# Out:
#        sepal_length  petal_length  petal_width
# count    150.000000    150.000000   148.000000
# mean       5.830000      3.758667     1.212838
# std        0.843829      1.764306     0.758380
# min        4.300000      1.000000     0.100000
# 25%        5.100000      1.525000     0.300000
# 50%        5.800000      4.350000     1.300000
# 75%        6.400000      5.100000     1.800000
# max        7.900000      6.900000     2.500000
